# %%
# Importing Libraries

import pandas as pd
import sklearn.model_selection as sk_ms
from sklearn.neighbors import KNeighborsClassifier
import sklearn.metrics as sk_m
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reading the DataFrame

faults_df = pd.read_csv("SteelPlateFaults-2class.csv")
print(faults_df)
# Out:
#       X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0          1325       1339      30207      30238           268           29
# 1             1         16      55572      55629           370           48
# 2          1323       1333      68445      68506           330           48
# 3          1324       1333      75642      75681           207           25
# 4          1324       1335      97132      97213           594           55
# ...         ...        ...        ...        ...           ...          ...
# 1114        250        373    3629947    3630060          6114          320
# 1115        243        370    3658370    3658511          7639          462
# 1116        241        360    3711661    3711800          7080          492
# 1117        836        878    2150529    2150756          5390          297
# 1118        414        438    2887460    2887476           263           29
#
#       Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 0              31              25809                     79
# 1              62              39293                     27
# 2              61              33449                     90
# 3              39              21354                     93
# 4              81              61608                     93
# ...           ...                ...                    ...
# 1114          197             633741                     40
# 1115          260             819375                     40
# 1116          293             773694                     43
# 1117          258             635678                      9
# 1118           17              30104                     87
#
#       Maximum_of_Luminosity  ...  Edges_X_Index  Edges_Y_Index  \
# 0                       124  ...         0.4828         1.0000
# 1                       119  ...         0.3125         0.9194
# 2                       119  ...         0.2083         1.0000
# 3                       124  ...         0.3600         1.0000
# 4                       125  ...         0.2000         1.0000
# ...                     ...  ...            ...            ...
# 1114                    134  ...         0.3844         0.5736
# 1115                    135  ...         0.2749         0.5423
# 1116                    140  ...         0.2419         0.4744
# 1117                    143  ...         0.1414         0.8798
# 1118                    134  ...         0.8276         0.9412
#
#       Outside_Global_Index  LogOfAreas  Log_X_Index  Log_Y_Index  \
# 0                      1.0      2.4281       1.1461       1.4914
# 1                      1.0      2.5682       1.1761       1.7559
# 2                      1.0      2.5185       1.0000       1.7853
# 3                      1.0      2.3160       0.9542       1.5911
# 4                      1.0      2.7738       1.0414       1.9085
# ...                    ...         ...          ...          ...
# 1114                   0.0      3.7863       2.0899       2.0531
# 1115                   1.0      3.8830       2.1038       2.1492
# 1116                   1.0      3.8500       2.0756       2.1430
# 1117                   1.0      3.7316       1.6233       2.3560
# 1118                   0.0      2.4200       1.3802       1.2041
#
#       Orientation_Index  Luminosity_Index  SigmoidOfAreas  Class
# 0                0.5484           -0.2476          0.7065      1
# 1                0.7368           -0.1703          0.9755      1
# 2                0.8361           -0.2081          0.8861      1
# 3                0.7692           -0.1941          0.5805      1
# 4                0.8642           -0.1897          0.9806      1
# ...                 ...               ...             ...    ...
# 1114            -0.0813           -0.1902          1.0000      0
# 1115             0.0993           -0.1620          1.0000      0
# 1116             0.1439           -0.1463          1.0000      0
# 1117             0.8150           -0.0786          1.0000      0
# 1118            -0.3333           -0.1058          0.6330      0
#
# [1119 rows x 28 columns]

# %%
# Splitting the data into train and test data

[X_train, X_test, X_label_train, X_label_test] = sk_ms.train_test_split(faults_df.iloc[::,:-1:], faults_df.Class, test_size=0.3, random_state=42,
shuffle=True)

print(X_train)
print()
print(X_test)
print()
print(X_label_train)
print()
print(X_label_test)
print()

# Saving to csv File

X_train.to_csv("SteelPlateFaults-train.csv", index = False)
X_test.to_csv("SteelPlateFaults-test.csv", index = False)
# Out:
#       X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 1114        250        373    3629947    3630060          6114          320
# 1009         37        217    1825287    1825355          6605          310
# 993          41        213    1637218    1637282          6206          257
# 254        1202       1216     289529     289543           137           15
# 820          43        215    1253069    1253240         13975          795
# ...         ...        ...        ...        ...           ...          ...
# 466         535        578     149538     149552           265           74
# 121         357        373     929482     929513           213           42
# 1044         41        213    2290146    2290212          5753          291
# 1095         86        215    7325485    7325536          4346          163
# 860          41        190    1799909    1800071         11388          705
#
#       Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 1114          197             633741                     40
# 1009          151             684731                     38
# 993           128             641502                     39
# 254            15              16692                    109
# 820           441            1630309                     29
# ...           ...                ...                    ...
# 466            46              32153                    114
# 121            39              20512                     80
# 1044          160             602131                     40
# 1095           89             473046                     65
# 860           420            1311391                     36
#
#       Maximum_of_Luminosity  ...  Outside_X_Index  Edges_X_Index  \
# 1114                    134  ...           0.0738         0.3844
# 1009                    126  ...           0.1327         0.5806
# 993                     127  ...           0.1268         0.6693
# 254                     134  ...           0.0083         0.9333
# 820                     140  ...           0.1229         0.2164
# ...                     ...  ...              ...            ...
# 466                     134  ...           0.0254         0.5811
# 121                     118  ...           0.0116         0.3810
# 1044                    125  ...           0.1267         0.5911
# 1095                    127  ...           0.0949         0.7914
# 860                     140  ...           0.1063         0.2113
#
#       Edges_Y_Index  Outside_Global_Index  LogOfAreas  Log_X_Index  \
# 1114         0.5736                   0.0      3.7863       2.0899
# 1009         0.4503                   0.0      3.8199       2.2553
# 993          0.5000                   0.0      3.7928       2.2355
# 254          0.9333                   0.5      2.1367       1.1461
# 820          0.3878                   0.0      4.1453       2.2355
# ...             ...                   ...         ...          ...
# 466          0.3043                   0.0      2.4232       1.6335
# 121          0.7949                   1.0      2.3284       1.2041
# 1044         0.4125                   0.0      3.7599       2.2355
# 1095         0.5730                   0.0      3.6381       2.1106
# 860          0.3857                   1.0      4.0564       2.1732
#
#       Log_Y_Index  Orientation_Index  Luminosity_Index  SigmoidOfAreas
# 1114       2.0531            -0.0813           -0.1902          1.0000
# 1009       1.8325            -0.6222           -0.1901          1.0000
# 993        1.8062            -0.6279           -0.1924          1.0000
# 254        1.1461             0.0000           -0.0481          0.3300
# 820        2.2330            -0.0058           -0.0886          1.0000
# ...           ...                ...               ...             ...
# 466        1.1461            -0.6744           -0.0521          0.8806
# 121        1.4914             0.4839           -0.2476          0.7844
# 1044       1.8195            -0.6163           -0.1823          1.0000
# 1095       1.7076            -0.6047           -0.1496          1.0000
# 860        2.2095             0.0803           -0.1003          1.0000
#
# [783 rows x 27 columns]
#
#       X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 243        1151       1162     866291     866302            85           14
# 101        1206       1214     308931     308956           134           12
# 961          43        198     686245     686304          6227          205
# 1060         41        216    2708878    2708939          6298          275
# 522          10         22    1269420    1269438           141           12
# ...         ...        ...        ...        ...           ...          ...
# 467          61         99    4757479    4757628          1970          210
# 424          21         74    5367324    5367377           784           66
# 689        1027       1048     787015     787022            76           22
# 595          24         44    1953869    1953891           240           25
# 65         1611       1619    1671950    1671963            69           10
#
#       Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 243            11              10211                    111
# 101            25              14838                    100
# 961           117             644765                     38
# 1060          134             654634                     42
# 522            19              15646                    105
# ...           ...                ...                    ...
# 467           181              29002                      0
# 424            54              82565                     67
# 689            10               9934                    109
# 595            22              29699                    107
# 65             14               5361                     63
#
#       Maximum_of_Luminosity  ...  Outside_X_Index  Edges_X_Index  \
# 243                     134  ...           0.0079         0.7857
# 101                     119  ...           0.0059         0.6667
# 961                     124  ...           0.1141         0.7561
# 1060                    126  ...           0.1289         0.6364
# 522                     124  ...           0.0087         1.0000
# ...                     ...  ...              ...            ...
# 467                      39  ...           0.0282         0.1810
# 424                     133  ...           0.0322         0.8030
# 689                     148  ...           0.0124         0.9546
# 595                     140  ...           0.0148         0.8000
# 65                       93  ...           0.0048         0.8000
#
#       Edges_Y_Index  Outside_Global_Index  LogOfAreas  Log_X_Index  \
# 243          1.0000                   0.5      1.9294       1.0414
# 101          1.0000                   1.0      2.1271       0.9031
# 961          0.5043                   0.0      3.7943       2.1903
# 1060         0.4552                   0.0      3.7992       2.2430
# 522          0.9474                   1.0      2.1492       1.0792
# ...             ...                   ...         ...          ...
# 467          0.8232                   1.0      3.2945       1.5798
# 424          0.9815                   0.5      2.8943       1.7243
# 689          0.7000                   0.0      1.8808       1.3222
# 595          1.0000                   1.0      2.3802       1.3010
# 65           0.9286                   1.0      1.8389       0.9031
#
#       Log_Y_Index  Orientation_Index  Luminosity_Index  SigmoidOfAreas
# 243        1.0414             0.0000           -0.0615          0.2300
# 101        1.3979             0.6800           -0.1349          0.3359
# 961        1.7708            -0.6194           -0.1911          1.0000
# 1060       1.7853            -0.6514           -0.1879          1.0000
# 522        1.2553             0.3333           -0.1331          0.3601
# ...           ...                ...               ...             ...
# 467        2.1732             0.7450           -0.8850          1.0000
# 424        1.7243             0.0000           -0.1772          1.0000
# 689        0.8451            -0.6667            0.0212          0.2621
# 595        1.3424             0.0909           -0.0332          0.7147
# 65         1.1139             0.3846           -0.3930          0.2105
#
# [336 rows x 27 columns]
#
# 1114    0
# 1009    0
# 993     0
# 254     1
# 820     0
#        ..
# 466     1
# 121     1
# 1044    0
# 1095    0
# 860     0
# Name: Class, Length: 783, dtype: int64
#
# 243     1
# 101     1
# 961     0
# 1060    0
# 522     1
#        ..
# 467     1
# 424     1
# 689     1
# 595     1
# 65      1
# Name: Class, Length: 336, dtype: int64

# %%
# K-Nearest Neighbour Analysis for K-value = 1

knn = KNeighborsClassifier(n_neighbors=1)  
knn.fit(X_train, X_label_train)
knn_predict = knn.predict(X_test)
conf_mat = sk_m.confusion_matrix(X_label_test, knn_predict)
print("Confusion Matrix for k = 1 is:")
print(conf_mat)
print()
print("Accuracy Score is:")
acc = sk_m.accuracy_score(X_label_test,knn_predict)
print(acc)
# Out:
# Confusion Matrix for k = 1 is:
# [[ 81  27]
#  [ 27 201]]
#
# Accuracy Score is:
# 0.8392857142857143

# %%
# Dictionary for storing accuracy scores for different k

acc_score = {1 : acc}
print(acc_score)
# Out:
# {1: 0.8392857142857143}

# %%
# Similar KNN Analysis for k = 3 and k = 5

for k in [3, 5]:
    knn = KNeighborsClassifier(n_neighbors=k)  
    knn.fit(X_train, X_label_train)
    knn_predict = knn.predict(X_test)
    conf_mat = sk_m.confusion_matrix(X_label_test, knn_predict)
    print("Confusion Matrix for k =" + str(k)+ " is:")
    print(conf_mat)
    print()
    print("Accuracy Score is:")
    acc = sk_m.accuracy_score(X_label_test,knn_predict)
    print(acc)
    acc_score[k] = acc
    print()
    print("------")
    print()
# Out:
# Confusion Matrix for k =3 is:
# [[ 83  25]
#  [ 12 216]]
#
# Accuracy Score is:
# 0.8898809523809523
#
# ------
#
# Confusion Matrix for k =5 is:
# [[ 82  26]
#  [  9 219]]
#
# Accuracy Score is:
# 0.8958333333333334
#
# ------

# %%
# Finding k-value for maximum classification accuracy

print(acc_score)
print()

(key1, val1) = (0, 0)
for k in acc_score:
    if val1 < acc_score[k]:
        (key1, val1) = (k, acc_score[k])

print("Max accuracy for k =", key1)
# Out:
# {1: 0.8392857142857143, 3: 0.8898809523809523, 5: 0.8958333333333334}
#
# Max accuracy for k = 5

# %%
# Loading test and train data to separate DataFrames

faults_train = pd.read_csv('SteelPlateFaults-train.csv')
faults_test=pd.read_csv('SteelPlateFaults-test.csv')

print(faults_train.head())
print(faults_test.head())
# Out:
#    X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0        250        373    3629947    3630060          6114          320
# 1         37        217    1825287    1825355          6605          310
# 2         41        213    1637218    1637282          6206          257
# 3       1202       1216     289529     289543           137           15
# 4         43        215    1253069    1253240         13975          795
#
#    Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 0          197             633741                     40
# 1          151             684731                     38
# 2          128             641502                     39
# 3           15              16692                    109
# 4          441            1630309                     29
#
#    Maximum_of_Luminosity  ...  Outside_X_Index  Edges_X_Index  Edges_Y_Index  \
# 0                    134  ...           0.0738         0.3844         0.5736
# 1                    126  ...           0.1327         0.5806         0.4503
# 2                    127  ...           0.1268         0.6693         0.5000
# 3                    134  ...           0.0083         0.9333         0.9333
# 4                    140  ...           0.1229         0.2164         0.3878
#
#    Outside_Global_Index  LogOfAreas  Log_X_Index  Log_Y_Index  \
# 0                   0.0      3.7863       2.0899       2.0531
# 1                   0.0      3.8199       2.2553       1.8325
# 2                   0.0      3.7928       2.2355       1.8062
# 3                   0.5      2.1367       1.1461       1.1461
# 4                   0.0      4.1453       2.2355       2.2330
#
#    Orientation_Index  Luminosity_Index  SigmoidOfAreas
# 0            -0.0813           -0.1902            1.00
# 1            -0.6222           -0.1901            1.00
# 2            -0.6279           -0.1924            1.00
# 3             0.0000           -0.0481            0.33
# 4            -0.0058           -0.0886            1.00
#
# [5 rows x 27 columns]
#    X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0       1151       1162     866291     866302            85           14
# 1       1206       1214     308931     308956           134           12
# 2         43        198     686245     686304          6227          205
# 3         41        216    2708878    2708939          6298          275
# 4         10         22    1269420    1269438           141           12
#
#    Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 0           11              10211                    111
# 1           25              14838                    100
# 2          117             644765                     38
# 3          134             654634                     42
# 4           19              15646                    105
#
#    Maximum_of_Luminosity  ...  Outside_X_Index  Edges_X_Index  Edges_Y_Index  \
# 0                    134  ...           0.0079         0.7857         1.0000
# 1                    119  ...           0.0059         0.6667         1.0000
# 2                    124  ...           0.1141         0.7561         0.5043
# 3                    126  ...           0.1289         0.6364         0.4552
# 4                    124  ...           0.0087         1.0000         0.9474
#
#    Outside_Global_Index  LogOfAreas  Log_X_Index  Log_Y_Index  \
# 0                   0.5      1.9294       1.0414       1.0414
# 1                   1.0      2.1271       0.9031       1.3979
# 2                   0.0      3.7943       2.1903       1.7708
# 3                   0.0      3.7992       2.2430       1.7853
# 4                   1.0      2.1492       1.0792       1.2553
#
#    Orientation_Index  Luminosity_Index  SigmoidOfAreas
# 0             0.0000           -0.0615          0.2300
# 1             0.6800           -0.1349          0.3359
# 2            -0.6194           -0.1911          1.0000
# 3            -0.6514           -0.1879          1.0000
# 4             0.3333           -0.1331          0.3601
#
# [5 rows x 27 columns]

# %%
# Min-Max Normalization in range 0-1 for train data

normalized_train = pd.DataFrame()
normalized_test = pd.DataFrame()
normal_max = 1
normal_min = 0
normal_range = normal_max - normal_min

for attribute in faults_train:
    
    if attribute == 'class':
        normalized_train[attribute] = faults_train[attribute]
        continue
        
    attribute_max = faults_train[attribute].max()
    attribute_min = faults_train[attribute].min()
    attribute_range = attribute_max - attribute_min
    
    normalized_train[attribute] = ((faults_train[attribute]-attribute_min) * (normal_range/attribute_range)) + normal_min
    normalized_test[attribute] = ((faults_test[attribute]-attribute_min) * (normal_range/attribute_range)) + normal_min
    
normalized_train.to_csv("SteelPlateFaults-train-Normalised.csv", index = False)
print(normalized_train.head())
print()
normalized_train.to_csv("SteelPlateFaults-test-normalised.csv", index = False)
print(normalized_test.head())
# Out:
#    X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0   0.146628   0.215916   0.291950   0.291958      0.163720     0.249804
# 1   0.021701   0.124634   0.146524   0.146528      0.176872     0.241948
# 2   0.024047   0.122294   0.131369   0.131373      0.166185     0.200314
# 3   0.704985   0.709187   0.022767   0.022767      0.003616     0.010212
# 4   0.025220   0.123464   0.100413   0.100425      0.374290     0.622938
#
#    Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 0     0.217295           0.161689               0.204082
# 1     0.166297           0.174703               0.193878
# 2     0.140798           0.163670               0.198980
# 3     0.015521           0.004197               0.556122
# 4     0.487805           0.416048               0.147959
#
#    Maximum_of_Luminosity  ...  Outside_X_Index  Edges_X_Index  Edges_Y_Index  \
# 0               0.449074  ...         0.082685       0.332176       0.519658
# 1               0.412037  ...         0.150046       0.545021       0.380759
# 2               0.416667  ...         0.143298       0.641245       0.436747
# 3               0.449074  ...         0.007777       0.927642       0.924862
# 4               0.476852  ...         0.138838       0.149924       0.310353
#
#    Outside_Global_Index  LogOfAreas  Log_X_Index  Log_Y_Index  \
# 0                   0.0    0.816019     0.645090     0.785154
# 1                   0.0    0.823886     0.704735     0.700792
# 2                   0.0    0.817541     0.697595     0.690734
# 3                   0.5    0.429796     0.304749     0.438296
# 4                   0.0    0.900073     0.697595     0.853952
#
#    Orientation_Index  Luminosity_Index  SigmoidOfAreas
# 0           0.464751          0.461501        1.000000
# 1           0.183120          0.461570        1.000000
# 2           0.180152          0.459986        1.000000
# 3           0.507081          0.559366        0.239501
# 4           0.504061          0.531474        1.000000
#
# [5 rows x 27 columns]
#
#    X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0   0.675073   0.677589   0.069245   0.069244      0.002223     0.009427
# 1   0.707331   0.708016   0.024330   0.024331      0.003536     0.007855
# 2   0.025220   0.113517   0.054736   0.054739      0.166747     0.159466
# 3   0.024047   0.124049   0.217727   0.217731      0.168649     0.214454
# 4   0.005865   0.010532   0.101730   0.101730      0.003723     0.007855
#
#    Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 0     0.011086           0.002542               0.566327
# 1     0.026608           0.003723               0.510204
# 2     0.128603           0.164503               0.193878
# 3     0.147450           0.167022               0.214286
# 4     0.019956           0.003930               0.535714
#
#    Maximum_of_Luminosity  ...  Outside_X_Index  Edges_X_Index  Edges_Y_Index  \
# 0               0.449074  ...         0.007319       0.767520       1.000000
# 1               0.379630  ...         0.005032       0.638425       1.000000
# 2               0.402778  ...         0.128774       0.735409       0.441591
# 3               0.412037  ...         0.145700       0.605554       0.386279
# 4               0.402778  ...         0.008234       1.000000       0.940746
#
#    Outside_Global_Index  LogOfAreas  Log_X_Index  Log_Y_Index  \
# 0                   0.5    0.381260     0.266994     0.398256
# 1                   1.0    0.427548     0.217122     0.534590
# 2                   0.0    0.817892     0.681295     0.677196
# 3                   0.0    0.819040     0.700299     0.682741
# 4                   1.0    0.432722     0.280625     0.480057
#
#    Orientation_Index  Luminosity_Index  SigmoidOfAreas
# 0           0.507081          0.550138        0.125993
# 1           0.861137          0.499587        0.246198
# 2           0.184578          0.460882        1.000000
# 3           0.167916          0.463085        1.000000
# 4           0.680621          0.500826        0.273666
#
# [5 rows x 27 columns]

# %%
# K-Nearest Neighbour Analysis for K-value = 1

knn = KNeighborsClassifier(n_neighbors=1)  
knn.fit(normalized_train, X_label_train)
knn_predict = knn.predict(normalized_test)
conf_mat = sk_m.confusion_matrix(X_label_test, knn_predict)
print("Confusion Matrix for k = 1 is:")
print(conf_mat)
print()
print("Accuracy Score is:")
acc = sk_m.accuracy_score(X_label_test,knn_predict)
print(acc)
# Out:
# Confusion Matrix for k = 1 is:
# [[104   4]
#  [  9 219]]
#
# Accuracy Score is:
# 0.9613095238095238

# %%
# Dictionary for storing accuracy scores for different k

acc_score = {1 : acc}
print(acc_score)
# Out:
# {1: 0.9613095238095238}

# %%
# Similar KNN Analysis for k = 3 and k = 5

for k in [3, 5]:
    knn = KNeighborsClassifier(n_neighbors=k)  
    knn.fit(normalized_train, X_label_train)
    knn_predict = knn.predict(normalized_test)
    conf_mat = sk_m.confusion_matrix(X_label_test, knn_predict)
    print("Confusion Matrix for k =" + str(k)+ " is:")
    print(conf_mat)
    print()
    print("Accuracy Score is:")
    acc = sk_m.accuracy_score(X_label_test,knn_predict)
    print(acc)
    acc_score[k] = acc
    print()
    print("------")
    print()
# Out:
# Confusion Matrix for k =3 is:
# [[105   3]
#  [  7 221]]
#
# Accuracy Score is:
# 0.9702380952380952
#
# ------
#
# Confusion Matrix for k =5 is:
# [[104   4]
#  [  7 221]]
#
# Accuracy Score is:
# 0.9672619047619048
#
# ------

# %%
# Finding k-value for maximum classification accuracy

print(acc_score)
print()

(key1, val1) = (0, 0)
for k in acc_score:
    if val1 < acc_score[k]:
        (key1, val1) = (k, acc_score[k])

print("Max accuracy for k =", key1)
# Out:
# {1: 0.9613095238095238, 3: 0.9702380952380952, 5: 0.9672619047619048}
#
# Max accuracy for k = 3
